# %%
import pandas as pd 
import matplotlib.pyplot as plt
import re
import tensorflow as tf
import tensorflow_datasets as tfds
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 4
#       2 import matplotlib.pyplot as plt
#       3 import re
# ----> 4 import tensorflow as tf
#       5 import tensorflow_datasets as tfds
#
# File c:\Users\mybae\anaconda3\envs\TORCH17_NLP38\lib\site-packages\tensorflow\__init__.py:38
#      35 import sys as _sys
#      36 import typing as _typing
# ---> 38 from tensorflow.python.tools import module_util as _module_util
#      39 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      41 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File c:\Users\mybae\anaconda3\envs\TORCH17_NLP38\lib\site-packages\tensorflow\python\__init__.py:42
#      37 from tensorflow.python.eager import context
#      39 # pylint: enable=wildcard-import
#      40
#      41 # Bring in subpackages.
# ---> 42 from tensorflow.python import data
#      43 from tensorflow.python import distribute
#      44 # from tensorflow.python import keras
#
# File c:\Users\mybae\anaconda3\envs\TORCH17_NLP38\lib\site-packages\tensorflow\python\data\__init__.py:21
#      15 """`tf.data.Dataset` API for input pipelines.
#      16
#      17 See [Importing Data](https://tensorflow.org/guide/data) for an overview.
#      18 """
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python.data import experimental
#      22 from tensorflow.python.data.ops.dataset_ops import AUTOTUNE
#      23 from tensorflow.python.data.ops.dataset_ops import Dataset
#
# File c:\Users\mybae\anaconda3\envs\TORCH17_NLP38\lib\site-packages\tensorflow\python\data\experimental\__init__.py:97
#      15 """Experimental API for building input pipelines.
#      16
#      17 This module contains experimental `Dataset` sources and transformations that can
#    (...)
#      93 @@UNKNOWN_CARDINALITY
#      94 """
#      96 # pylint: disable=unused-import
# ---> 97 from tensorflow.python.data.experimental import service
#      98 from tensorflow.python.data.experimental.ops.batching import dense_to_ragged_batch
#      99 from tensorflow.python.data.experimental.ops.batching import dense_to_sparse_batch
#
# File c:\Users\mybae\anaconda3\envs\TORCH17_NLP38\lib\site-packages\tensorflow\python\data\experimental\service\__init__.py:419
#       1 # Copyright 2020 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """API for using the tf.data service.
#      16
#      17 This module contains:
#    (...)
#     416   job of ParameterServerStrategy).
#     417 """
# --> 419 from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#     420 from tensorflow.python.data.experimental.ops.data_service_ops import from_dataset_id
#     421 from tensorflow.python.data.experimental.ops.data_service_ops import register_dataset
#
# File c:\Users\mybae\anaconda3\envs\TORCH17_NLP38\lib\site-packages\tensorflow\python\data\experimental\ops\data_service_ops.py:22
#      20 from tensorflow.core.protobuf import data_service_pb2
#      21 from tensorflow.python import tf2
# ---> 22 from tensorflow.python.data.experimental.ops import compression_ops
#      23 from tensorflow.python.data.experimental.service import _pywrap_server_lib
#      24 from tensorflow.python.data.experimental.service import _pywrap_utils
#
# File c:\Users\mybae\anaconda3\envs\TORCH17_NLP38\lib\site-packages\tensorflow\python\data\experimental\ops\compression_ops.py:16
#       1 # Copyright 2020 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Ops for compressing and uncompressing dataset elements."""
# ---> 16 from tensorflow.python.data.util import structure
#      17 from tensorflow.python.ops import gen_experimental_dataset_ops as ged_ops
#      20 def compress(element):
#
# File c:\Users\mybae\anaconda3\envs\TORCH17_NLP38\lib\site-packages\tensorflow\python\data\util\structure.py:22
#      18 import itertools
#      20 import wrapt
# ---> 22 from tensorflow.python.data.util import nest
#      23 from tensorflow.python.framework import composite_tensor
#      24 from tensorflow.python.framework import ops
#
# File c:\Users\mybae\anaconda3\envs\TORCH17_NLP38\lib\site-packages\tensorflow\python\data\util\nest.py:34
#       1 # Copyright 2017 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      16 """## Functions for working with arbitrarily nested sequences of elements.
#      17
#      18 NOTE(mrry): This fork of the `tensorflow.python.util.nest` module
#    (...)
#      31    arrays.
#      32 """
# ---> 34 from tensorflow.python.util import nest_util
#      37 def is_nested(structure):
#      38   return nest_util.is_nested(nest_util.Modality.DATA, structure)
#
# File c:\Users\mybae\anaconda3\envs\TORCH17_NLP38\lib\site-packages\tensorflow\python\util\nest_util.py:35
#      33 from tensorflow.python import pywrap_tensorflow  # pylint: disable=unused-import
#      34 from tensorflow.python.platform import tf_logging
# ---> 35 from tensorflow.python.util import _pywrap_utils
#      36 from tensorflow.python.util.compat import collections_abc as _collections_abc
#      39 _is_mapping_view = _pywrap_utils.IsMappingView
#
# ImportError: DLL load failed while importing _pywrap_utils: 지정된 프로시저를 찾을 수 없습니다.

# %%
# !pip install -c conda-forge tensorflow-datasets -y

# %%
# !conda install -c conda-forge tensorflow -y
# Out:
# Channels:
#  - conda-forge
#  - defaults
#  - anaconda
#  - pytorch
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\mybae\anaconda3\envs\TORCH17_NLP38
#
#   added / updated specs:
#     - tensorflow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     intel-openmp-2019.4        |              245         1.4 MB
#     libmklml-2019.0.5          |       haa95532_0        17.5 MB
#     mkl-2023.2.0               |   h6a75c08_49573       138.0 MB  conda-forge
#     numpy-1.23.5               |   py38h6917f2d_1          11 KB
#     numpy-base-1.23.5          |   py38h46c4fa8_1         5.0 MB
#     scipy-1.10.1               |   py38h1aea9ed_3        17.4 MB  conda-forge
#     tensorflow-2.3.0           |mkl_py38h3c6dea5_0           6 KB
#     tensorflow-base-2.3.0      |mkl_py38ha8c2253_0        65.3 MB
#     ------------------------------------------------------------
#                                            Total:       244.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   libmklml           pkgs/main/win-64::libmklml-2019.0.5-haa95532_0
#
# The following packages will be UPDATED:
#
#   mkl                pkgs/main::mkl-2023.1.0-h6b88ed4_46358 --> conda-forge::mkl-2023.2.0-h6a75c08_49573
#   scipy              pkgs/main::scipy-1.10.1-py38hdcfc7df_1 --> conda-forge::scipy-1.10.1-py38h1aea9ed_3
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   tensorflow-base    anaconda::tensorflow-base-2.3.0-eigen~ --> pkgs/main::tensorflow-base-2.3.0-mkl_py38ha8c2253_0
#
# The following packages will be DOWNGRADED:
#
#   intel-openmp                      2023.1.0-h59b6b97_46320 --> 2019.4-245
#   numpy                               1.24.3-py38h79a8e48_1 --> 1.23.5-py38h6917f2d_1
#   numpy-base                          1.24.3-py38h8a87ada_1 --> 1.23.5-py38h46c4fa8_1
#   tensorflow                       2.3.0-mkl_py38h8c0d9a2_0 --> 2.3.0-mkl_py38h3c6dea5_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
df = pd.read_csv('data/cleaned_data.csv')
df
# Out:
#            field                                           question  \
# 0      재판, 소송 절차   남해상속상담 부탁드립니다.본인이 부동산을 상속 받는 게 부모님 유언이라고 우기고 ...
# 1         신용, 파산   안성개인회생전문 사무실 찾고 있어요.상담 좀 받고 싶은데., 채무가 많아요. 저도...
# 2         신용, 파산  평택시개인회생전문 변호사 추천부탁드려요. 대출금을 상환하지 못해 현재 개인회생 신청...
# 3      재판, 소송 절차  구미학교폭력변호사님 저희 아들 이야기입. 구미학교폭력변호사님 부모로써 대응할것입니다...
# 4      재판, 소송 절차  동생이랑 제가 나이차이가 많이납니다.그리고 동생이 어렸을 때부터 대학 들어갈 때까지...
# ...          ...                                                ...
# 71258        성범죄  형사재판 성폭력으로 1심 무죄를 받았습니. 형사재판 성폭력으로 1심 무죄를받았습니다...
# 71259  재판, 소송 절차  항소 기각 될 확률 알고 십으요 폭행치상 죄로 법정에서 7개원 정도 싸웠고요 검사 ...
# 71260  재판, 소송 절차  형사공판 2심에 관한 질문검사가 항소 제가 피의자입니다.여성입니다.통신매체이용음란죄...
# 71261       형사사건  강제추행 1심에서 무죄판결 내려졌습니다. 강제추행 1심에서 무죄판결 내려졌습니다 그...
# 71262  재판, 소송 절차  항소심 유죄 내공100 여자친구가 1심에서 무죄를받고현재 항소 재판기일이 나왔습니다...
#
#                                                   answer
# 0         질문자님의 공동상속인이 유언이라 말하는 동영상이  녹음유언의 조건에 부합는지 ...
# 1         안성개인회생전문 변호사사무실 찾는 질문에 답변 드립니다. 개인회생의 성공은 곧...
# 2         평택시개인회생전문 변호사 찾는 질문에 답변 드립니다. 개인회생은 법적으로 채무...
# 3         질문자님, 글 작성해주신 교내 학교폭력 관련하여 구미학교폭력변호사가 직접 답변...
# 4         질문자님, 글 작성해주신 유류분 반환 관련하여 대구상속로펌에서 직접 설명 드리...
# ...                                                  ...
# 71258   서울지방변호사회네이버 지식iN 상담 변호사 이재호 입니다.  1심에서 심리가 충분...
# 71259   서울지방변호사회네이버 지식iN 상담 변호사 이재호 입니다.  1심에서 심리가 충분...
# 71260   서울지방변호사회네이버 지식iN 상담 변호사 이재호 입니다.  1심에서 심리가 충분...
# 71261   서울지방변호사회네이버 지식iN 상담 변호사 이재호 입니다.  1심에서 심리가 충분...
# 71262   서울지방변호사회네이버 지식iN 상담 변호사 이재호 입니다.  1심에서 심리가 충분...
#
# [71263 rows x 3 columns]

# %%
# 단어 집합 생성

questions = []
for q in df['question']:
    q = re.sub(r"([?.!,])", r" \1 ", q)
    q = q.strip()
    questions.append(q)

answers = []
for a in df['answer']:
    a = re.sub(r"([?.!,])", r" \1 ", a)
    a = a.strip()
    answers.append(a)

# %%
tokenizer = tfds.deprecated.text.SubwordTextEncoder.build_from_corpus(
    questions + answers, target_vocab_size=2**13)

# 시작 토큰과 종료 토큰 추가
START_TOKEN, END_TOKEN = [tokenizer.vocab_size], [tokenizer.vocab_size + 1]

VOCAB_SIZE = tokenizer.vocab_size + 2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 tokenizer = tfds.deprecated.text.SubwordTextEncoder.build_from_corpus(
#       2     questions + answers, target_vocab_size=2**13)
#       4 # 시작 토큰과 종료 토큰 추가
#       5 START_TOKEN, END_TOKEN = [tokenizer.vocab_size], [tokenizer.vocab_size + 1]
#
# NameError: name 'tfds' is not defined
