# %%
import pandas as pd
import re

# %%
# 데이터 확인 후 전처리 함수 생성

# 정규표현식을 사용하여 문장 전처리
def remove_repeated_punctuation(sentence):
    # 한글, 영어, 숫자만 포함되도록 정규표현식 수정
    cleaned_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣a-zA-Z0-9\s]', '', sentence)
    # 반복되는 'ㅠ', 'ㅎ', 'ㅋ'을 지움
    cleaned_sentence = re.sub(r'(ㅠ)\1+', r'\1', cleaned_sentence)
    cleaned_sentence = re.sub(r'(ㅎ)\1+', r'\1', cleaned_sentence)
    cleaned_sentence = re.sub(r'(ㅋ)\1+', r'\1', cleaned_sentence)
    # 반복되는 구두점을 지움
    cleaned_sentence = re.sub(r'([^\w\s])\1+', r'\1', cleaned_sentence)
    return cleaned_sentence

def predata_to_csv(df, repeat_sentences,mode = 'a'):
    # 결측치 제거
    df.dropna(inplace = True)
    # 한 열이라도 빈문자열인 행 제거
    df = df.drop(index=df[df.apply(lambda row: row.str.strip().eq('')).any(axis=1)].index)
    # 중복되는 인사말 제거
    df['answer'] = df['answer'].str.replace('안녕하세요.','')
    for r in repeat_sentences:
        df['answer'] = df['answer'].str.replace(re.escape(r), '', regex=True)
    # 반복 구두점 및 단어 제거
    df['answer'] = df['answer'].apply(remove_repeated_punctuation)
    df['question'] = df['question'].apply(remove_repeated_punctuation)
    print(df)
    if mode == 'w':
        df.to_csv('rawal_data.csv', mode = 'w', index=False)
    else:
        df.to_csv('rawal_data.csv', mode = 'a', index = False, columns = None)

# %%
gDF = pd.read_csv('./권진원.csv')
gment = ['서울지방변호사회 소속으로 지식iN 법률상담을 진행하고 있는 권진원 변호사입니다.','경주형사전문변호사가 답변 도와드리겠습니다']
predata_to_csv(gDF,gment,'w')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 gDF = pd.read_csv('./권진원.csv')
#       2 gment = ['서울지방변호사회 소속으로 지식iN 법률상담을 진행하고 있는 권진원 변호사입니다.','경주형사전문변호사가 답변 도와드리겠습니다']
#       3 predata_to_csv(gDF,gment,'w')
#
# File c:\Users\mybae\anaconda3\envs\TORCH17_NLP38\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\mybae\anaconda3\envs\TORCH17_NLP38\lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File c:\Users\mybae\anaconda3\envs\TORCH17_NLP38\lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\mybae\anaconda3\envs\TORCH17_NLP38\lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File c:\Users\mybae\anaconda3\envs\TORCH17_NLP38\lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './권진원.csv'

# %%
kDF = pd.read_csv('./김정묵.csv')
kment = ['서울지방 변호사회 소속으로 지식iN 법률상담을 진행하고 있는 김정묵 변호사입니다','서울지방변호사회 소속으로 지식iN 법률상담을 진행하고 있는 김정묵 변호사입니다.','창세 법률사무소 http://changselaw.com 상담대표변호 1566-6107 https://open.kakao.com/o/sgmubYfg','​법률 상담이 필요하시다면 망설이지 마시고 편하게 연락 주시면 상담 도와드리겠습니다. 감사합니다.']
predata_to_csv(kDF, kment,'a')
# Out:
#           field                                           question  \
# 0            민법  상가 화재로 인한 보상청구 및 소송문제 도 저희가 임차인으로 들어간 건물 옆에서 화...
# 1          강력범죄  구속영장실질검사 구속확률 폭행사건 공동감금으로 조사받고있습니다 검찰에서도 조사를받았...
# 2     교통 사고, 위반  책임보험으로 사고가나서 민사소송이 들어 21년도에 제가 책임보험이고 상대차량 후미를...
# 3          민사소송  상간녀 소송 질문 남편이 제가 아파서 병원에 입원했을때 다른 여성과 모텔에 갔었고 ...
# 4        공갈, 협박  협박무고죄정보통신법 고소당했어요 안녕하세요다름아닌 요약을해서 말씀을드리면여러사건으로...
# ...         ...                                                ...
# 2600       손해배상  킥보드 뺑소니 무면허로 킥보드를 탔는데 제가 아이랑 부딪치게 되었어요멀리서부터 아이...
# 2601  재판, 소송 절차  유언장 작성방법 혼자 살고 있구요 수급자인데임대 아파트 본인이 죽으면 보증금1상속 ...
# 2602    부동산, 건축  종중회 부동산 소유권 변경 저희 아버지 대가 23대손이고 23대손종중회가 있으며 2...
# 2603       민사소송  전화상담 신청 할수 있나요 안녕하세요 이번 민사사건 으로 인해 전화상담 신청할수 있을까요
# 2604       재산범죄  부경법 배임죄 고소를 당할수있나요 업종은 소도매 유통업체입니다 종류는 청량음료 라면...
#
#                                                  answer
# 0        불행하게도 이러한 상황에서 화재보험이 없는 경우 손해를 배상받기가 어려울 수 ...
# 1        피해자와 피의자의 진술이 엇갈리는 상황에서는 구속 여부를 결정하는 데에 영향을...
# 2        말씀해주신 사안으로 봤을때는 고소가 된것이 아니라 보험사로부터 구상금 청구를 ...
# 3        질문자님께서 말씀해주신 내용만으로 정확하게 판단할수는 없지만 일반적으로 부정한...
# 4        구체적인 사실관계를 모르는 상황에서 대략적인 정보만 제공해드릴 수 있는 점 양...
# ...                                                 ...
# 2600     1 혐의 귀하의 경우 도로교통법상 무면허 운전 교통사고처리특례법상 뺑소니 혐의...
# 2601     1 상속 순위 LH 기준의 상속 순위는 다음과 같습니다 배우자 직계 비속 직계...
# 2602     1 위와 같이 종중 외의 자에게 부동산 등기 이전이 가능한지요 결론부터 말씀드...
# 2603     네 전화상담 신청이 가능합니다  상담 신청 시 다음과 같은 사항을 준비하시면 ...
# 2604     결론부터 말씀드리면 부정경쟁방지법 위반이나 업무상 배임죄로 고소를 당할 가능성...
#
# [2531 rows x 3 columns]

# %%
ohDF = pd.read_csv('./오지영.csv')
ohment = ['서울지방변호사회 소속으로 지식iN 법률상담을 진행하고 있는 오지영 변호사입니다.','힘들고 복잡한 법률 문제, 혼자 고민하지 마시고 언제든지 전화주세요  법률상담 전화번호 010-7494-2459']
predata_to_csv(ohDF, ohment,'a')
# Out:
#          field                                           question  \
# 0       가족, 이혼  집명의는 제 명의이고 담보대출은 전남편 남편의 외도로 이혼 하면서대출은 전남편이 계...
# 1         재산범죄  미국에서 상속자 없이 죽으면 재산은 국고 미국에서 상속자 없이자기 가족 또 누구에게...
# 2           계약  상가임대시 다운계약서 상가임대 계약하면서 임대인분이 본인 세금이 너무 많이 나온다며...
# 3         형사사건  구약식에 정식재판청구하면 무조건 벌금 증 명예훼손으로 200만원 정도 예상하고 있습...
# 4           계약  전문공사업체 불법하도급계약시 처벌 전문공사업종간 하도급계약은 불법인것으로 알고 있습...
# ..         ...                                                ...
# 438       형사사건  참고인 조사 피고발인 조사 질문드려요 제가 부산에 사는데 서울 소재 경찰서에서 법위...
# 439  재판, 소송 절차  전남친 폭행 채무불이행 지금 제 동생의 전남자친구이하 전남친가 200만원 가량의 돈...
# 440       민사소송  상간녀 변경 전화번호 확인방법 문의 상간녀가 핸폰 변경 후에 사라져버렸는데 개인적으...
# 441     공갈, 협박  협박죄 성립 연인 사이에서 다툼이 일어나 메신저로 말싸움을 하다가 상대방이 중간에 ...
# 442       민사소송  모욕죄 민사소송 피소를 당했습니다 2021년에 있던 일이고카톡 단톡방에서 시비를 걸...
#
#                                                 answer
# 0    남편의 외도로 이혼 하면서 대출은 전남편이 계속 채무를 부담하고 가지고 가기로 하고...
# 1        미국에서 상속자 없이 사망 시 재산 귀속에 대한 질문에 답변드리겠습니다 1 ...
# 2       상가 임대 계약 시 다운계약서를 작성하여 실제 월세보다 낮은 금액으로 세무서에...
# 3       구약식 정식 재판 청구 시 벌금 증액 가능성에 대해 문의하셨습니다 답변드리겠습...
# 4        전문공사업종간 하도급 계약의 불법성과 관련하여 문의하셨습니다 답변드리겠습니다...
# ..                                                 ...
# 438     담당 형사의 조치 가능성 참고인에서 피고발인으로 변경 가능 조사 과정에서 혐의...
# 439     1 민사 소송 대여금 청구 소송 200만원 부채에 대한 변제를 청구하는 소송 ...
# 440     상간녀의 개인정보를 불법적으로 획득하거나 활용하는 것은 엄격히 금지됩니다 상간...
# 441     협박죄 성립 요건 고의성 상대방에게 두려움을 느끼게 하는 의도가 있어야 함 폭...
# 442     1 이의제기 vs 답변서 이의제기 소장 내용에 대한 불복 의사를 법원에 서면으...
#
# [426 rows x 3 columns]

# %%
uDF = pd.read_csv('./유성권.csv')
ument = ['대전모욕죄변호사 유성권 변호사입니다','대전변호사 유성권 변호사 사시52회 입니다',
'대전상속변호사 유성권 변호사 사시52회입니다','대전합의서변호사 유성권입니다',
'대전변호사 유성권 입니다','대전이혼전문변호사  유성권입니디','대전변호사 유성권 변호사 사시52회입니다',
'대전변호사 유성권 변호사입니다','개인회생변호사 유성권 변호사입니다','로톡네이버 지식iN 상담변호사 유성권 입니다',
'로시컴-네이버 지식iN 상담변호사 유성권 입니다.','대전이혼변호사  유성권 변호사입니다',
'대전상해죄변호사 유성권 변호사 사시52회입니다','대전변호사 유성권 변호사 사시52회입니다','대전전세사기변호사 유성권 변호사입니다',
'대전경찰조사 변호사 유성권 변호사입니다']
predata_to_csv(uDF, ument, 'a')
# Out:
#             field                                           question  \
# 0            강력범죄  마약전문변호사님 억울해요 살 빼려고 산 다이어트약이 마약이라네요진짜 몰랐는데 이것도...
# 1          신용, 파산  개인회생 변호사비용 어떻게 되나요 개인회생 변호사비용이 궁금합니다 광고에서는 자세한...
# 2          신용, 파산  개인회생전문변호사 법무법인 상담 요청해 개인회생전문변호사 알아보는데 어디서 알아봐야...
# 3          신용, 파산  개인회생변호사 궁금한데요 개인회생 하시는 분들은 다 개인회생변호사를 알아보고 하시나...
# 4          신용, 파산  개인회생변호사비용 얼마나 필요한가요 30대이고 공무원으로 재직중입니다개인회생을 하려...
# ...           ...                                                ...
# 9930  언론, 미디어 관련법  명예훼손 고소 억울 일하던 회사에서 좋지 않은 일이 터졌어요범인을 찾겠다고 하더니전...
# 9931         강력범죄  가정에서 누군가가 폭력을 유발해 폭력당했 가정에서 누군가가 폭력을 유발해 폭력당했다...
# 9932  언론, 미디어 관련법  병신인가라고 댓글달았는데 모욕죄고소되나 얼굴이랑 다나와있는 인스타캡쳐글에 댓글로 병...
# 9933    재판, 소송 절차  피고소인도 증거자료 제출되나요 돈문제 때문에 채무자에게 계속 폭언 문자보내다가 정보...
# 9934           사기  사기특경가중처벌 선고기일이 공판기일로 변경되고 변론하라고 하네여ㅜㅜ피해자랑 합의하려...
#
#                                                  answer
# 0          고의성이 없었음을 일관되게 주장하시길 권해드립니다  마약관련하여 전화로도 ...
# 1          구체적인 사정에 따라 수임료는 달라질 수 있으나 상대적으로 저렴하게 진행이...
# 2          개인회생관련하여 전화로도 법률상담이 가능합니다    로시컴네이버 지식iN ...
# 3          개인회생관련하여 법률상담 가능하며 전국사건 진행 가능합니다  전화로도 개인...
# 4          구체적인 내용 채무의 수등에 따라 수임료는 달라질 수 있습니다  상대적으로...
# ...                                                 ...
# 9930                              무고죄 고소를 고려해 볼 수 있습니다
# 9931                  단순히  폭행을 유도했다는사정만으로 처벌이 되지는 않습니다
# 9932   로톡네이버 지식iN 상담변호사 유성권 입니다    병신도 모욕이 될 수 있으며 특...
# 9933   로톡네이버 지식iN 상담변호사 유성권 입니다  혐의없음으로 종결된 사안이므로  고...
# 9934             연기사유를 기재하여  공판기일연기신청서를 제출해 보시길 권해드립니다
#
# [9827 rows x 3 columns]

# %%
yDF = pd.read_csv('./윤세라.csv')
yment = ['귀하의 상황을 안타깝게 생각하며, 소송을 통해 문제를 해결하고자하는 결정에 도움을 드리고자 합니다.','서울지방변호사회 소속으로 지식iN 법률상담을 진행하고 있는 윤세라 변호사입니다.','상담을 원하시면 언제든지 편하게 연락 주세요. 친절한 상담으로 도와드리겠습니다.  ""법무법인 아이엠 법률 상담 전화번호 010-3893-2982"" ']
predata_to_csv(yDF, yment,'a')
# Out:
#       field                                           question  \
# 0      강력범죄  누범기간 특수상해 2020년도 절도로인해 2년6월 형을받아 22년도11월 만기출소하...
# 1       경범죄  남양주형사전문변호사 명예훼손 잘 아시는 온라인 카페에 익명으로 올라온 글도 명예훼손...
# 2      강력범죄  고소가능한가요 전 배우자가 부모님집에 위장전입 하고연락을 피하고 저희 사는곳 근처에...
# 3        민법  유언공증해놓고매각 아버지가 돌아가시면 내연녀에게 건물을 준다고유언공증돌아가시기전에공...
# 4      형사사건  마약전문변호사 필요할거 같습니다 마약 거래 관련으로 동생이 구속되어 있는데 조만간 ...
# ..      ...                                                ...
# 881      사기  보이스피싱 피해구제신청후 진행중 피해구제까지신청완료하고 하루하루피말라가며 살고있는데...
# 882    민사소송  상간남 소송 결혼 4년차 자녀 둘입니다배우자 외도는 2개월 정도 된거 같은데요위자료...
# 883  가족, 이혼  베트남 전통결혼한후1달뒤에 신부가 이혼 급하게 한국에서 혼인신고도 했는데벳여가 한국...
# 884    강력범죄  중고사기 조사 이후 안녕하세요 피해금은 54만원이고 1명입니다중고사기로 경찰 조사후...
# 885  가족, 이혼  가정폭력 해당 안녕하세요 나이는 22살 여자입니다 제가 친구들이랑 가끔씩 술먹고 들...
#
#                                                 answer
# 0         정확한 법률적 판단과 도움을 위해 변호사와 상담하는 것을 가장 우선적으로 ...
# 1         온라인 카페에 익명으로 올라온 글도 명예훼손으로 고소 가능성이 있습니다 특...
# 2         전 배우자의 위장 전입은 민법상 불법행위에 해당할 수 있지만 형사처벌 대상...
# 3       아버지께서 내연녀에게 건물을 증여하겠다는 유언을 작성하셨고 돌아가시기 전에 건...
# 4       마약 전문 변호사는 동생의 사건을 담당하여 다음과 같은 전문적인 역할을 수행합...
# ..                                                 ...
# 881    피해 구제 신청을 완료하셨는데 가족들이 모르게 하다 보니 전화 한 통 쉽게 못 ...
# 882    배우자의 외도는 큰 정신적 고통과 피해를 줄 수 있으며 이에 대한 위자료 청구는...
# 883    국제 결혼한 지 얼마 되지 않은 배우자가 이혼을 요구한다니 상심이 크시리라 짐작...
# 884    사건이 검찰로 넘어갔다면 담당 검사가 경찰에서 조사한 기록을 바탕으로 처분을 결...
# 885    귀하의 경우 가정폭력으로 볼 수 있습니다 가정폭력은 배우자 직계존속 직계비속 형...
#
# [849 rows x 3 columns]

# %%
imDF = pd.read_csv('./임동규.csv')
imment = ['서울지방변호사회 소속으로 지식iN 법률상담을 진행하고 있는 임동규 변호사입니다.','상담을 원하시면 언제든지 편하게 연락 주세요. 친절한 상담으로 도와드리겠습니다.  ""법무법인 아이엠 법률 상담 전화번호 010-6551-1332""']
predata_to_csv(imDF,imment, 'a')
# Out:
#         field                                           question  \
# 0         성범죄  성추행기준 궁금합니다 안녕하세요성추행기준 궁금해서 여기에 질문 남겨요제가 알바를 하...
# 1        재산범죄  합의 이혼 문의 7년 결혼생활중에아내가 합의이혼을 요구합니다 모든 재산 위자료는 포...
# 2     부동산, 건축  배우자 부동산 임의 처분에 대한 질문 안녕하십니까 아내는 평생 가사 이외에 아무런 ...
# 3          민법  상속 관련 질문드립니다 처형이 배우자 없이 아들 한 명 있는 상태로유언없이 사망하였...
# 4          강도  음주 0178 초범 처벌 제가 회식하고 오늘 새벽 건천 톨게이트 고속도로갓길에 음주...
# ...       ...                                                ...
# 3052     민사소송  보험사기피고입장 민사소송후 부당이득반 과거 보험사기 일당 8명과 모의하여 고의사고 ...
# 3053     강력범죄  업무방해죄 가 부  역고소 고묭노동부 공무윈이 질의자를 상대로 2022년 9윌 부터...
# 3054     형사사건  인천 변호사 무료상담 가능한곳있을까요ㅠ 안녕하세요 다름이아니라 접촉사고후 가해자쪽에...
# 3055       사기  취업알선사기 1아들을 취업시켜준다고 a씨가 계속 유인하여춰업관계자 라고 b씨를 소개...
# 3056     재산범죄  빌려준돈 형사고소 지인이 급하게 처리해야될일이있는데 현금 융통이안돼서 재산내역을 일...
#
#                                                  answer
# 0        귀하가 질문하신 내용에 대한 답변 드리겠습니다  가게 매니저 오빠의 행위가 성...
# 1        합의이혼 및 재산분할 관련 질문에 대한 답변 입니다  합의이혼 시 작성한 재산...
# 2        귀하가 질문하신 내용에 대한 답변 드리겠습니다  근저당을 설정하면 아파트를 처...
# 3        상속 관련 문의에 대한 답변 입니다  처형님이 유언을 남기지 않았기 때문에 법...
# 4        음주운전으로 인한 조사 및 벌금 관련 문의에 대한 답변 입니다  귀하의 혈중알...
# ...                                                 ...
# 3052     개인별로 7백여만 원을 각각 받아내는 것인지 아니면 9인 모드 합해 7백여만 ...
# 3053     아래 내용은 문의 내용에 기초하여 작성된 것으로 구체적인 사정에 따라 결론이 ...
# 3054     현재 귀하가 받고 계신 욕설과 협박 문자 메시지 등은 심각한 사안으로 보일 수...
# 3055     취업 알선 사기는 범죄로 간주될 수 있습니다 취업 알선 사기의 피해자인 경우 ...
# 3056     지인이 돈을 빌려 간 것에 대해 거짓말을 한 경우 이는 사기로 간주될 수 있습...
#
# [2973 rows x 3 columns]

# %%
emDF = pd.read_csv('./임동호.csv')
emment = ['서울지방변호사회 소속으로 지식iN 법률상담을 진행하고 있는 임동호 변호사입니다.','상담을 원하시면 언제든지 편하게 연락 주세요. 친절한 상담으로 도와드리겠습니다.  법무법인 아이엠 법률 상담 전화번호 010-2895-1338""']
predata_to_csv(emDF,emment,'a')
# Out:
#          field                                           question  \
# 0    교통 사고, 위반  음주운전처벌기준 재범 경우에 어떻게 되나 아들이 음주운전 또 해서 걸렸다고 하네요그...
# 1    교통 사고, 위반  교통사고 종결 합의금 질문 드립니다 버스와 사고로 과실 본인60으로 가해자 입니다1...
# 2    교통 사고, 위반  부산교통사고변호사 도움이 될까요 음주운전사고 관련해서는 부산교통사고변호사 진행하는게...
# 3       가족, 이혼  아내가 이혼소송을 준비중 입니다 제가 5년전 아내가 임신 출산때 몇년간 외도를 하였...
# 4       가족, 이혼  이혼전문변호사상담 요청드립니다 아내 바람때문에 지금 미치겠습니다아내 직장이 아니라 ...
# ..         ...                                                ...
# 959         폭행  폭행 문의 제가 피해자 입장사건개요가해자측이 약간의 말다툼끝에 갑작스레 양손으로 어...
# 960       형사사건  음주운전벌금감면 안되나요 음주 초범으로 걸렸는데 벌금이 너무 높게 나온 거 같아서요...
# 961       재산범죄  소송관련문의드려요 1 회사유상증자때 회사등기임원이 대표가시켰다고 자신계좌에서 직원계...
# 962     가족, 이혼  황혼이혼후 사망한 배우자 가족관계등록부 사망한 배우자와 재결합을 통해 가족관계등록부...
# 963        행정법  행정소송 겅제이행금 강제이행금은 얼마로 책정하나요문서를 공개하라고 판결났는데 이행안...
#
#                                                 answer
# 0       아들의 음주운전 재범으로 인해 안타까운 마음을 표현드립니다 매번 음주운전하지 ...
# 1       합의금 지급 가능성 및 금액 합의금 지급 가능성 본인의 경우 입원 치료 기간이...
# 2       음주운전 사고는 피해 규모가 크고 법률적 쟁점이 복잡하기 때문에 전문 변호사의...
# 3       현재 이혼 소송에 직접적인 영향은 없을 것으로 예상됩니다 다만 아내가 과거 외...
# 4       현재 겪고 계신 극심한 감정과 혼란스러운 상황을 이해하며 법률 전문가의 도움을...
# ..                                                 ...
# 959     이의 신청 불송치결 결과에 동의하지 않는다면 7일 이내에 이의 신청을 할 수 ...
# 960     음주운전 벌금 음주운전 벌금은 혈중알코올농도 운전경력 과거 음주운전 경력 사고...
# 961     임원의 행위는 횡령 또는 배임에 해당할 가능성이 높습니다 임원은 직원들에게 회...
# 962     재결합 불가능 이러한 법적 근거에 따라 사망한 배우자와는 재결합이 불가능합니다...
# 963     강제이행금은 판결 내용에 따라 법원이 정한 금액입니다 일반적으로 일정 금액을 ...
#
# [941 rows x 3 columns]

# %%
jDF = pd.read_csv('./장은영.csv')
jment = ['서울지방변호사회 소속으로 지식iN 법률상담을 진행하고 있는 장은영 변호사입니다.','법률 상담이 필요하시다면 망설이지 마시고 편하게 연락 주시면 상담 도와드리겠습니다. 감사합니다. ​ ​​“법률 상담 전화번호 010-5689-4495”']
predata_to_csv(jDF,jment)
# Out:
#           field                                           question  \
# 0          민사소송  지급명령 폐문부재 반복 지급명령신청을 해서 송달을 하는데 폐문부재로 인해 송달이 되...
# 1          민사소송  소멸시효 연장문의 10년전 민사판결문물품대금을 받고 소멸시효가 다가와서 연장을 하려...
# 2          강력범죄  고소가능한가요 전 배우자가 부모님집에 위장전입 하고연락을 피하고 저희 사는곳 근처에...
# 3          민사소송  민사소송  대략적인 비용을 알고싶습니다 제가 매장 공사를하는 과정에서 인테리어 업자...
# 4       부동산, 건축  전세 집주인 개인회생을 하고 있습니다 h 안녕하세요 법률 자문을 구하고자 글을 남깁...
# ...         ...                                                ...
# 1817         사기  가상화폐 채굴을 빙자한 사기 피해 2019년 경 평소 알고 지내던 A씨가 어머니에게...
# 1818       손해배상  내가 처방받지 않은약에대한 일로 대한 손 안녕하세요오늘 오후 헌혈전 문진 및 이상여...
# 1819  교통 사고, 위반  대인 교통사고 차에 스쳐 뺑소니라고 주 얼마전 지인께서 상가주변 통행로에서 운전하고...
# 1820       민사소송  주차장에서 자동차 훼손시 책임 저는 빌라에 살고 있습니다 5층에 있는 한 가구에 전...
# 1821       손해배상  약처방을 잘못해줬을 경우 저희 어머니가 당뇨가 있어서 당뇨약을 처방받아 먹고 있습니...
#
#                                                  answer
# 0        첫째 채무자의 거주 여부를 정확히 파악해야 합니다 채무자에게 직접 연락하여 거...
# 1        소장 접수 및 소멸시효 소장 종류 물품대금 청구권의 소멸시효 연장을 위해서는 ...
# 2        위장전입은 형사상의 범죄로 간주될 수 있습니다 대부분의 국가에서는 위장전입이나...
# 3        민사소송의 비용은 다양한 요소에 따라 달라질 수 있습니다 일반적으로 변호사 비...
# 4         1 집 호수 및 채권자 오류 정정 요청 누가 정정 요청해야 하는지 본인 빠른...
# ...                                                 ...
# 1817     귀하의 경우 A씨가 어머니에게 3000만원을 빌린 후 변제하지 않고 있는 사기...
# 1818     귀하는 해당 약국에 손해배상을 청구할 수 있습니다  귀하는 약국에서 피니스테라...
# 1819     귀하의 지인의 경우 다음과 같은 방법으로 대처할 수 있습니다 경찰 조사에 성실...
# 1820     귀하의 경우 주차장 관리에 소홀하여 석회물이 떨어져 차량이 훼손된 경우로 보입...
# 1821     귀하의 어머니께서 당뇨약 대신 고관절약과 진통제를 20일 동안 복용하셨다고 하...
#
# [1772 rows x 3 columns]

# %%
leeDF = pd.read_csv('./data/이재호.csv')
leement = ['서울지방변호사회 소속으로 지식iN 법률상담을 진행하고 있는 이재호 변호사입니다.','서울지방변호사회네이버 지식iN 상담 변호사 이재호 입니다']
predata_to_csv(leeDF,leement)
# Out:
#          field                                           question  \
# 0         강력범죄  아청법이나 통매음 적용 아청법이나 통매음은 성인과 미성년자에 대화일때 상대방이 불쾌...
# 1          성범죄                      성희롱한 엔지니어 경찰서가서 어디과에 가면 신고되나요
# 2          성범죄  공중여자화장실 무단출입건 월요일 밤 10시경 대변이 마려워 화장실을 찾다가 공중화장...
# 3          성범죄  유아성추행 처벌만 알려주세요 다른건 묻지 마시고 유아성추행 처벌만 알려주십시오제가 ...
# 4          성범죄  기습뽀뽀 정도도 추행 더러운 세상 마음에 드는 사람이 잇어 기습뽀뽀를 햇습디다키스도...
# ...        ...                                                ...
# 48875  형벌, 형집행  집행유예2년 음주운전 2회로 집행유예2년을 받게되면전과자로 남는다 들었습니다혹시 실...
# 48876       폭행  회사동료에게 폭행을 당해 5주의 진단을 받 회사동료에게 폭행을 당해 5주의 진단을 ...
# 48877      경범죄  네이버 밴드 테러 고소 가능한가요 제가 운영하는 밴드인데요 누가 약간 저를 까는 글...
# 48878     형사사건  토토 처벌 수위질문 제가 다른분에게 입금하여 그사람이 직접사이트에충전후환급받고 수익...
# 48879      성범죄  익명 게시판에서 제가 쓴글이 다른 사이트 제가 예전에 익명으로 글을 썼는데 글에서 ...
#
#                                                   answer
# 0         상대방과 합의하에 이루어지는 행위는 원칙적으로 처벌대상이 아닙니다 다만 일정한...
# 1         성희롱은 상대방이 원하지 않는 성적인 말이나 행동을 하여 상대방에게 성적 굴욕...
# 2         성적목적으로 화장실에 침입하는 경우에는 성적목적다중이용장소침입죄가 성립될 수 ...
# 3         13세미만의 미성년자에 대한 강제추행죄의 법정형은 5년이상의 유기징역이나 범행...
# 4         의사에 반한 또는 강제폭행 또는 협박로 성적 수치심이나 혐오감을 느낄 정도의 ...
# ...                                                  ...
# 48875   서울지방변호사회네이버 지식iN 상담 변호사 이재호 입니다  집행유예는 벌금형보다 ...
# 48876   서울지방변호사회네이버 지식iN 상담 변호사 이재호 입니다  고소하기 전에 합의를 ...
# 48877   서울지방변호사회네이버 지식iN 상담 변호사 이재호 입니다  비방할 목적으로 SNS...
# 48878   서울지방변호사회네이버 지식iN 상담 변호사 이재호 입니다  초범 재범의 여부 및 ...
# 48879   서울지방변호사회네이버 지식iN 상담 변호사 이재호 입니다  문의하신 사안의 경우 ...
#
# [48020 rows x 3 columns]

# %%
rawalDF = pd.read_csv('./rawal_data.csv')
rawalDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20938 entries, 0 to 20937
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   field     20938 non-null  object
#  1   question  20938 non-null  object
#  2   answer    20938 non-null  object
# dtypes: object(3)
# memory usage: 490.9+ KB

# %%
rawalDF.head()
# Out:
#        field                                           question  \
# 0  재판, 소송 절차  의정부개인파산전문 변호사 선임 꼭 해야 의정부개인파산 신청하려고 합니다알아보니 개인...
# 1     신용, 파산  남양주개인회생 대출받은게 감당이 안됩니 남양주개인회생 가까운 로펌 찾고있습니다빠르게...
# 2  재판, 소송 절차  전세 대항력 확실하게 말해주세요 안녕하십니까 전세 대항력 의문점이 많습니다이렇게 글...
# 3  재판, 소송 절차  대구교통사고변호사 조언 간절합니다 대구교통사고변호사 있을까요 제발 봐주십시오출근길에...
# 4  재판, 소송 절차  경주형사전문변호사 잘하는 곳으로ㅠ 경주형사전문변호사님 소개 부탁드립니다제가 음주운전...
#
#                                               answer
# 0    의정부개인파산 질문에 답변 드립니다  개인파산제도는 자신의 모든 재산으로도 채무...
# 1     남양주개인회생 로펌 찾는 질문에 답변 드립니다  개인회생 제도는 신청인의 지역...
# 2     질문자님 글 작성해주신 전세 대항력 관련하여 대구 변호사가 직접 답변을 드립니...
# 3     질문자님 글 작성해주신 교통사고 뺑소니 관련하여 대구교통사고변호사가 직접 설명...
# 4       혹시 측정을 거부하셨나요  이 경우에는 음주운전측정거부 측정불응죄에 해당이...
